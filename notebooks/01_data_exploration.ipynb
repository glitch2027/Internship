# %%
import pandas as pd
import glob
import os

# %%
# Load all CSV datasets from data/raw
raw_dir = '../data/raw'
csv_files = glob.glob(os.path.join(raw_dir, '*.csv'))

datasets = {}
for file in csv_files:
    name = os.path.basename(file)
    datasets[name] = pd.read_csv(file)

# Print .shape, .dtypes, and .head() for each
for name, df in datasets.items():
    print(f'--- {name} ---')
    print(f'Shape: {df.shape}')
    print(f'Data Types:\n{df.dtypes}')
    print(f'Head:\n{df.head()}\n')
# Out:
# --- axis_bluechip_nav.csv ---
# Shape: (3608, 4)
# Data Types:
# date               str
# nav            float64
# scheme_code      int64
# scheme_name        str
# dtype: object
# Head:
#          date        nav  scheme_code    scheme_name
# 0  31-07-2026  6251.9433       119092  Axis Bluechip
# 1  30-07-2026  6249.5705       119092  Axis Bluechip
# 2  29-07-2026  6248.7985       119092  Axis Bluechip
# 3  28-07-2026  6248.4821       119092  Axis Bluechip
# 4  27-07-2026  6246.9483       119092  Axis Bluechip
#
# --- hdfc_top_100_direct_nav.csv ---
# Shape: (3134, 4)
# Data Types:
# date               str
# nav            float64
# scheme_code      int64
# scheme_name        str
# dtype: object
# Head:
#          date       nav  scheme_code          scheme_name
# 0  31-07-2026  204.7896       125497  HDFC Top 100 Direct
# 1  30-07-2026  204.8096       125497  HDFC Top 100 Direct
# 2  29-07-2026  207.1837       125497  HDFC Top 100 Direct
# 3  28-07-2026  206.0616       125497  HDFC Top 100 Direct
# 4  27-07-2026  206.7707       125497  HDFC Top 100 Direct
#
# --- icici_bluechip_nav.csv ---
# Shape: (3350, 4)
# Data Types:
# date               str
# nav            float64
# scheme_code      int64
# scheme_name        str
# dtype: object
# Head:
#          date       nav  scheme_code     scheme_name
# 0  31-07-2026  111.5685       120503  ICICI Bluechip
# 1  30-07-2026  110.6762       120503  ICICI Bluechip
# 2  29-07-2026  110.3876       120503  ICICI Bluechip
# 3  28-07-2026  109.3376       120503  ICICI Bluechip
# 4  27-07-2026  109.3678       120503  ICICI Bluechip
#
# --- kotak_bluechip_nav.csv ---
# Shape: (3344, 4)
# Data Types:
# date               str
# nav            float64
# scheme_code      int64
# scheme_name        str
# dtype: object
# Head:
#          date       nav  scheme_code     scheme_name
# 0  31-07-2026  252.2089       120841  Kotak Bluechip
# 1  30-07-2026  251.6049       120841  Kotak Bluechip
# 2  29-07-2026  253.4389       120841  Kotak Bluechip
# 3  28-07-2026  250.1527       120841  Kotak Bluechip
# 4  27-07-2026  251.2699       120841  Kotak Bluechip
#
# --- nippon_large_cap_nav.csv ---
# Shape: (3341, 4)
# Data Types:
# date               str
# nav            float64
# scheme_code      int64
# scheme_name        str
# dtype: object
# Head:
#          date       nav  scheme_code       scheme_name
# 0  31-07-2026  101.8133       118632  Nippon Large Cap
# 1  30-07-2026  101.5563       118632  Nippon Large Cap
# 2  29-07-2026  101.4265       118632  Nippon Large Cap
# 3  28-07-2026  100.2374       118632  Nippon Large Cap
# 4  27-07-2026  100.4498       118632  Nippon Large Cap
#
# --- sbi_bluechip_nav.csv ---
# Shape: (3279, 4)
# Data Types:
# date               str
# nav            float64
# scheme_code      int64
# scheme_name        str
# dtype: object
# Head:
#          date       nav  scheme_code   scheme_name
# 0  31-07-2026  106.8377       119551  SBI Bluechip
# 1  30-07-2026  106.7842       119551  SBI Bluechip
# 2  29-07-2026  106.8357       119551  SBI Bluechip
# 3  28-07-2026  106.8611       119551  SBI Bluechip
# 4  27-07-2026  106.8126       119551  SBI Bluechip

# %%
# Explore fund master
if 'fund_master.csv' in datasets:
    df = datasets['fund_master.csv']
    print('Unique Fund Houses:', df['fund_house'].unique() if 'fund_house' in df.columns else 'N/A')
    print('Unique Categories:', df['category'].unique() if 'category' in df.columns else 'N/A')
    print('Unique Sub-Categories:', df['sub_category'].unique() if 'sub_category' in df.columns else 'N/A')
    print('Unique Risk Grades:', df['risk_grade'].unique() if 'risk_grade' in df.columns else 'N/A')

# %%
# Validate AMFI codes
if 'fund_master.csv' in datasets and 'nav_history.csv' in datasets:
    master_codes = set(datasets['fund_master.csv']['amfi_code'].dropna().astype(str))
    nav_codes = set(datasets['nav_history.csv']['amfi_code'].dropna().astype(str))
    missing = master_codes - nav_codes
    print(f'Codes in fund_master missing in nav_history: {len(missing)}')
    if len(missing) == 0:
        print('All AMFI codes validate successfully!')
    else:
        print(f'Data Quality Issue: {len(missing)} codes missing.')
